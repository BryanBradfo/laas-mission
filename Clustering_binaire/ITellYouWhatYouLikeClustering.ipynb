# %% [markdown]
# # **Tell Me What You Want, I'll Tell You What You Like**
#
# In this file, we try to use a better clustering approach (exploration then exploitation)
#
# ## DOcplex Python API installation
#
# First, we install the docplex python API which we will use for modelling our problem and solving it. (Then, we will not have problem size error)

# %%
import sys
try:
    import docplex.mp
except:
    if hasattr(sys, 'real_prefix'):
        # !pip install docplex -q
        print("!pip install docplex -q...")
    else:
        # !pip install --user docplex -q
        print("!pip install --user docplex -q...")
        
print("End of the intallation of python API...")
# Out:
# End of the intallation of python API...

# %% [markdown]
# ## Main code

# %%
#############################
### Import libraries ###
#############################

from docplex.cp.model import *
from Solver import *
from User import *

# %%
#############################
### Essentials functions ###
#############################
#import functionMain du dossier parent
import sys
sys.path.append("..")
import FunctionMain as fm
import my_clustering as my_cl

# %%
# ----------------- Parameters

# The file to consider
file = '../file_with_optimal_val/la04.txt'

# The number of solutions that we will have in the solver during the first iteration
k = 10

# The number of layer which is fixed
nb_layers = 5

# Variable which display the solution
display_sol = False

# Variable which display the start (in a vector)
display_start = False

# Variable which display the start (in a matrix)
display_matrix = False

# Time stop criterion 
tps_max = 700

# Number of iteration stop criterion
it_max = 70




# The number of solutions that we will have in the solver after the first iteration
k_k = 15

list_search_type = ["DepthFirst", "Restart", "MultiPoint", "IterativeDiving"]
#############################
### Main program ###
#############################

print("\n--------Main program is loading...---------")

# --------- Interaction with the solver
data = []
n, m, data, T_machine, T_duration, duration, optimalval = fm.get_data_from_file(file)

# --------- Call Solver constructor in Solver.py and create the variables of the model
model, solver, starts = fm.initialize_solver(data, n, m, duration)

model, variables = solver.create_constraints(model, n, m, optimalval, T_machine)

# ------------ Solve the model
print("\nSolving the model...")
msol, nb_solution, runtime = solver.solve(model, k_k, n, m, variables)


# ------------ Display the result
fm.display_solution(msol, display_sol)
print("Model solved !")

# ---------------- Interaction with the user
print("\n--------Interaction with the user...---------")
print("\nCreating the user...")
user = User()
print("User created !")

#Get the variables of the model
variables = solver.get_variables()

list_indice, list_obj, pref, list_layers, list_equal = fm.user_preferences(msol, user, nb_layers, n, m)

# Vector of the start time of each task of each preference
starts = user.start_pref(n, m, display_start)

# Matrix of the start time of each task of each preference
matrix = user.matrix_pref(n, m, display_matrix)

# Testing the order of preferences and the differences between solutions
fm.test(n, m, user)

print("list layers : ",list_layers)
# Out:
# --------Main program is loading...---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# Model solved !
#
# --------Interaction with the user...---------
#
# Creating the user...
# User created !
#
# Classing solutions...
# Le min de list_obj est 3945
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
# list layers :  [[<docplex.cp.solution.CpoSolveResult object at 0x0000021906B12DC0>, <docplex.cp.solution.CpoSolveResult object at 0x000002190186D2C0>, <docplex.cp.solution.CpoSolveResult object at 0x000002190A4EA040>, <docplex.cp.solution.CpoSolveResult object at 0x000002190450CC40>, <docplex.cp.solution.CpoSolveResult object at 0x0000021904BA9C40>], [<docplex.cp.solution.CpoSolveResult object at 0x0000021909B014C0>, <docplex.cp.solution.CpoSolveResult object at 0x000002190157ED40>], [<docplex.cp.solution.CpoSolveResult object at 0x00000219068B2C40>, <docplex.cp.solution.CpoSolveResult object at 0x00000219037D2140>, <docplex.cp.solution.CpoSolveResult object at 0x000002190A83BDC0>, <docplex.cp.solution.CpoSolveResult object at 0x0000021903B99E40>], [<docplex.cp.solution.CpoSolveResult object at 0x000002190B0BC2C0>, <docplex.cp.solution.CpoSolveResult object at 0x000002190AB87640>, <docplex.cp.solution.CpoSolveResult object at 0x000002190AB87840>], [<docplex.cp.solution.CpoSolveResult object at 0x0000021906B129C0>]]

# %%
####################################################################
#### Exploration: RECHERCHE DE NOUVELLES SOLUTIONS 
####################################################################


###  -------------- Iteration of the solver with the preferences
it = 1
tps = runtime
list_min_obj = [min(list_obj)]
list_min_obj_global = [min(list_obj)]
it_max_exploration = 0.75*it_max
tps_max_exploration = 0.75*tps_max
criterion = (tps < tps_max_exploration) and (it < it_max_exploration) 

# ----------------- Add the preferences to the model
while criterion :
    print("\n--------Iteration {}---------".format(it))
    it += 1

    # --------- Call Solver constructor in Solver.py and create the variables of the model
    model, solver, starts = fm.initialize_solver(data, n, m, duration)

    # --------- Add the new constraints to the model (that solution must be different from the previous generated solutions)
    variables = fm.update_variables_new_constraint(n, m,  pref, model, solver)
    
    # # --------- Add the constraints considering the clustering
    
    list_rayon_layers, list_start_sol_layers, dict_sol_rayon  = my_cl.list_rayon_binaire_cluster(n, m, list_layers)
    list_rayon_layers_flatten = [item for sublist in list_rayon_layers[1:] for item in sublist]
    list_start_sol_layers_flatten = [item for sublist in list_start_sol_layers[1:] for item in sublist]
         
    for l in range(len(list_rayon_layers_flatten)):
        solver.add_constraint(model, my_cl.manhattan_binaire_distance_contrainte(list_start_sol_layers_flatten[l], [model.start_of(variables[i//m][i%m]) for i in range(n*m)]) > list_rayon_layers_flatten[l])
               
            
    # --------- Add the constraints considering the clustering
    model, variables = solver.create_constraints(model, n, m, optimalval, T_machine)

    # ------------ Solve the model
    print("\nSolving the model...")
    msol, nb_solution, runtime = solver.solve(model, k_k, n, m, variables)

    print("The number of solutions generated is :",nb_solution)
    list = []
    for sol in msol:
        list.append(user.objectiveFunction(sol) + user.objectiveFunctionRegularity(sol, n, m))
        # list.append(user.objectiveFunction(sol) * user.objectiveFunctionRegularity(sol, n, m))

    list_min_obj.append(min(list))
    print("Objective function :", list_min_obj)

    # ------------ Display the result
    fm.display_solution(msol, display_sol)
    print("Model solved !")

    # ---------------- Interaction with the user
    list_indice, list_obj, pref, list_layers, list_equal = fm.user_preferences(msol, user, nb_layers, n, m)
    print("Il y a {} solution(s)".format(len(pref)))

    list_min_obj_global.append(min(list_obj))
    print("Objective function global :", list_min_obj_global)

    # Vector of the start time of each task of each preference
    starts = user.start_pref(n, m, display_start)

    # Matrix of the start time of each task of each preference
    matrix = user.matrix_pref(n, m, display_matrix)

    # Testing the order of preferences and the differences between solutions
    fm.test(n, m, user)

#------------------ Condition d'arrêt ------------------
    tps += runtime
    criterion = (tps < tps_max_exploration) and (it < it_max_exploration) 
    fm.stopCondition(it, it_max_exploration, tps, tps_max_exploration)
it_final_exploration = it
# Out:
# --------Iteration 1---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 4537
# Objective function : [3945, 4101]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3945
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 30 solution(s)
# Objective function global : [3945, 3945]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 2---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 4370
# Objective function : [3945, 4101, 3882]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3882
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 45 solution(s)
# Objective function global : [3945, 3945, 3882]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 3---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 3793
# Objective function : [3945, 4101, 3882, 4182]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3882
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 60 solution(s)
# Objective function global : [3945, 3945, 3882, 3882]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 4---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 3051
# Objective function : [3945, 4101, 3882, 4182, 3946]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3882
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 75 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 5---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 2270
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3882
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 90 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 6---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 1879
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 105 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 7---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 1462
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 120 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 8---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 1312
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 135 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 9---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 1130
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 150 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 10---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 877
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 165 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 11---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 768
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 180 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 12---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 738
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 195 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 13---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 798
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 210 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 14---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 878
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 225 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 15---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 866
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 240 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 16---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 820
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 255 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 17---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 603
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3880
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 270 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 18---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 590
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 285 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 19---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 767
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 300 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 20---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 750
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 315 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 21---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 787
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 330 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 22---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 667
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 345 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 23---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 560
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 360 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 24---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# The number of solutions generated is : 695
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5481
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 375 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
# The user has reached the maximum time !

# %%
# # Plot du minimum de l'objectif parmis les nouvelles solutions générées

# import matplotlib.pyplot as plt
# print(list_min_obj)
# plt.plot([i for i in range(it)], list_min_obj, label='min obj', marker='o')
# plt.xlabel("Iteration")
# plt.ylabel("makespan")
# plt.title("Evolution of the makespan for generate solutions")
# plt.xticks(range(it))
# plt.legend()
# plt.show() 

# Print it_max exploration
print("\n--------End of the exploration---------")
print("The number of iterations is :", it)
print(list_min_obj_global)
# Out:
# --------End of the exploration---------
# The number of iterations is : 25
# [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875]

# %%
# Plot du minimum de l'objectif parmis les solutions générées so far

#print(list_min_obj_global)
# plt.plot([i for i in range(it)], list_min_obj_global, label='min obj', marker='o')
# plt.xlabel("Iteration")
# plt.ylabel("makespan")
# plt.title("Evolution of the best makespan so far")
# plt.xticks(range(it))
# plt.legend()
# plt.show()

# %%
####################################################################
#### Exploitation: RECHERCHE DE NOUVELLES SOLUTIONS 
####################################################################


###  -------------- Iteration of the solver with the preferences
k_k = 4

criterion = (tps < tps_max) and (it < it_max) 
# ----------------- Add the preferences to the model
while criterion :
    print("\n--------Iteration {}---------".format(it))
    it += 1

    # --------- Call Solver constructor in Solver.py and create the variables of the model
    model, solver, starts = fm.initialize_solver(data, n, m, duration)

    # --------- Add the new constraints to the model (that solution must be different from the previous generated solutions)
    variables = fm.update_variables_new_constraint(n, m,  pref, model, solver)
    
    # # --------- Add the constraints considering the clustering
    
    list_rayon_layers, list_start_sol_layers, dict_sol_rayon  = my_cl.list_rayon_binaire_cluster(n, m, list_layers)
    
    list_cluster_layers = my_cl.my_clustering_binaire(n, m, list_rayon_layers, list_layers)

    list_centroides_layers = my_cl.centroides_clusters(n, m, list_cluster_layers)

    sum = 0
    for i in range(len(list_centroides_layers)): #On parcourt les layers
        sum_temp = 0
        for j in range(len(list_centroides_layers[i])): #On parcourt les clusters
            sum_temp += my_cl.manhattan_binaire_distance_contrainte(list_centroides_layers[i][j], [model.start_of(variables[i//m][i%m]) for i in range(n*m)])
        sum_temp *= len(list_centroides_layers)-i 
    sum += sum_temp
    model.add(minimize(sum))


    # list_rayon_layers_flatten = [item for sublist in list_rayon_layers[1:] for item in sublist]
    # list_start_sol_layers_flatten = [item for sublist in list_start_sol_layers[1:] for item in sublist]
         
    # for l in range(len(list_rayon_layers_flatten)):
    #     solver.add_constraint(model, my_cl.manhattan_binaire_distance_contrainte(list_start_sol_layers_flatten[l], [model.start_of(variables[i//m][i%m]) for i in range(n*m)]) > list_rayon_layers_flatten[l])
    

   

    # ------------ Solve the model
    print("\nSolving the model...")
    
    model, variables = solver.create_constraints(model, n, m, optimalval, T_machine)
    msol, nb_solution, runtime = solver.solve(model, k_k, n, m, variables)

    print("The number of solutions generated is :",nb_solution)
    list = []
    for sol in msol:
        list.append(user.objectiveFunction(sol)+user.objectiveFunctionRegularity(sol, n, m))
        # list.append(user.objectiveFunction(sol) * user.objectiveFunctionRegularity(sol, n, m))

    list_min_obj.append(min(list))
    print("Objective function :", list_min_obj)

    # ------------ Display the result
    fm.display_solution(msol, display_sol)
    print("Model solved !")

    # ---------------- Interaction with the user
    list_indice, list_obj, pref, list_layers, list_equal = fm.user_preferences(msol, user, nb_layers, n, m)
    print("Il y a {} solution(s)".format(len(pref)))

    list_min_obj_global.append(min(list_obj))
    print("Objective function global :", list_min_obj_global)

    # Vector of the start time of each task of each preference
    starts = user.start_pref(n, m, display_start)

    # Matrix of the start time of each task of each preference
    matrix = user.matrix_pref(n, m, display_matrix)

    # Testing the order of preferences and the differences between solutions
    fm.test(n, m, user)

#------------------ Condition d'arrêt ------------------
    tps += runtime
    criterion = (tps < tps_max) and (it < it_max) 
    fm.stopCondition(it, it_max, tps, tps_max)
# Out:
# --------Iteration 25---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 14
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 379 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 26---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 12
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 383 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 27---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 12
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3875
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 387 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 28---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 12
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 391 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 29---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 12
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 395 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 30---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 12
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 399 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 31---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 14
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 403 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 32---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 14
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 407 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 33---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 11
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 411 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 34---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 11
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 415 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 35---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 11
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 419 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 36---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 11
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 423 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 37---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 13
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 427 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 38---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 13
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 431 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 39---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 13
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 435 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 40---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 13
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 439 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 41---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 13
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 443 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 42---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 13
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5566
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 447 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 43---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 12
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 451 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 44---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 455 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 45---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 459 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 46---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 463 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 47---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 467 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 48---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 471 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 49---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 475 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 50---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 479 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 51---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 483 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 52---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 487 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 53---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 491 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 54---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 495 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 55---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 499 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 56---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 503 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 57---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 507 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 58---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 511 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 59---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 515 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 60---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 519 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 61---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 523 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 62---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454, 3893]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 527 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 63---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454, 3893, 4588]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 531 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 64---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454, 3893, 4588, 4588]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 535 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 65---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454, 3893, 4588, 4588, 3896]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 539 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 66---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454, 3893, 4588, 4588, 3896, 4458]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 543 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 67---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454, 3893, 4588, 4588, 3896, 4458, 4588]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 547 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 68---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454, 3893, 4588, 4588, 3896, 4458, 4588, 4460]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 551 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 69---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Solving the model...
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# The number of solutions generated is : 9
# Objective function : [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454, 3893, 4588, 4588, 3896, 4458, 4588, 4460, 4462]
# Model solved !
#
# Classing solutions...
# Le min de list_obj est 3860
# Le max de list_obj est 5696
# Solutions classed !
#
# Creating preferences...
# Preferences created !
# Il y a 555 solution(s)
# Objective function global : [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
# The user has reached the maximum number of iterations !

# %%
# Plot du minimum de l'objectif parmis les nouvelles solutions générées

import matplotlib.pyplot as plt
print(list_min_obj)
plt.plot([i for i in range(it)], list_min_obj, label='min obj', marker='o')
plt.axvline(x=it_final_exploration, color='r', linestyle='--', label='it final exploration')
plt.xlabel("Iteration")
plt.ylabel("makespan")
plt.title("Evolution of the makespan for generate solutions")
plt.xticks(range(it))
plt.legend()
plt.show()
# Out:
# [3945, 4101, 3882, 4182, 3946, 4211, 3880, 3980, 3923, 3939, 3992, 3984, 4148, 3942, 3949, 4051, 4228, 3942, 3875, 4141, 3989, 4032, 4084, 4032, 4040, 5387, 4618, 4428, 3860, 3863, 4696, 3866, 4592, 4624, 4432, 4434, 4626, 4594, 3869, 4436, 4666, 4690, 4618, 5494, 3872, 3875, 4506, 3878, 4440, 4666, 3881, 4588, 4444, 3884, 4446, 3887, 4602, 4448, 4450, 3890, 4588, 4454, 3893, 4588, 4588, 3896, 4458, 4588, 4460, 4462]

# %%
# Plot du minimum de l'objectif parmis les solutions générées so far

print(list_min_obj_global)
plt.plot([i for i in range(it)], list_min_obj_global, label='min obj', marker='o')
plt.xlabel("Iteration")
plt.ylabel("makespan")
plt.title("Evolution of the best makespan so far")
plt.xticks(range(it))
plt.legend()
plt.show()
# Out:
# [3945, 3945, 3882, 3882, 3882, 3882, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3880, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3875, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860, 3860]

# %%
import main_cb as cb
list_min_obj, list_min_obj_global = cb.main_cb('../file_with_optimal_val/la04.txt', "test0", 5, 20, 15, 100, 10, "plus")
# Out:
# --------Main program is loading...---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Solving the model...
# Model solved !
#
# --------Interaction with the user...---------
#
# Creating the user...
# User created !
#
# Classing solutions...
# Le min de list_obj est 3951
# Le max de list_obj est 5431
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 1---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Classing solutions...
# Le min de list_obj est 3904
# Le max de list_obj est 5431
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 2---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Classing solutions...
# Le min de list_obj est 3851
# Le max de list_obj est 5431
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 3---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Classing solutions...
# Le min de list_obj est 3851
# Le max de list_obj est 5431
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
# The user has reached the maximum time !
#
# --------Iteration 4---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Classing solutions...
# Le min de list_obj est 3851
# Le max de list_obj est 5530
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 5---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# Le nombre de solutions demandé est supérieur à la taille de la liste.
#
# Classing solutions...
# Le min de list_obj est 3851
# Le max de list_obj est 5530
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 6---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# Le nombre de solutions demandé est supérieur à la taille de la liste.
#
# Classing solutions...
# Le min de list_obj est 3851
# Le max de list_obj est 5530
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 7---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# Le nombre de solutions demandé est supérieur à la taille de la liste.
#
# Classing solutions...
# Le min de list_obj est 3851
# Le max de list_obj est 5530
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 8---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
#
# Classing solutions...
# Le min de list_obj est 3851
# Le max de list_obj est 5582
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
#
# --------Iteration 9---------
#
# Creating the model variables...
# Model tasks_by_jobs created !
#
# Solver initialized !
#
# Adding precedence constraints to the solver...
# Precedence constraints added !
#
# Adding disjunctive constraints to the solver...
# Disjunctive constraints added !
# Le nombre de solutions demandé est supérieur à la taille de la liste.
#
# Classing solutions...
# Le min de list_obj est 3851
# Le max de list_obj est 5582
# Solutions classed !
#
# Creating preferences...
# Preferences created !
#
# Testing order of preferences...
# 	L'ordre des préférences n'est pas cohérente
#
# Testing differences between solutions...
# 	Toutes les solutions sont différentes
# The user has reached the maximum number of iterations !
